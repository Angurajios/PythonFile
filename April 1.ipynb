# %% [markdown]
# Data Structures ----> List,tuple,set,dictionary
#
# #List
#
# --collection of values with different types
# --Duplicates allowed
# --Mutable
# --Ordered

# %%
list1 = ["apple","banana",1,2,3.3,4,5,6,7,89]
list1[5]
# Out:
# 4

# %%
list2 = ["apple","banana",1,2,3.3,4,5,6,7,89]
list2[-2]
# Out:
# 7

# %%
#slicing

#lastValue is exculded value

#stepValue must be one addtional if 2 it will skip 1, if 3 it will skip 2

here index upto 8 but to print all values we need to give 9 as last value

cart = ["toys","apple","banana",1,2,3,4,5]

cart[0:9]
# Out:
# ['toys', 'apple', 'banana', 1, 2, 3, 4, 5]

# %%
cart1 = ["toys","apple","banana",1,2,3,4,5]

cart1[0:9:2]
# Out:
# ['toys', 'banana', 2, 4]

# %%
cart2 = ["toys","apple","banana",1,2,3,4,5]

cart2[0:9:3]
# Out:
# ['toys', 1, 4]

# %%
cart3 = ["toys","apple","banana",1,2,3,4,5]

cart3[::-1]
# Out:
# [5, 4, 3, 2, 1, 'banana', 'apple', 'toys']

# %%
cart4 = ["toys","apple","banana",1,2,3,4,5]

cart4[1:8:2]
# Out:
# ['apple', 1, 3, 5]

# %%
str = "Anguraj"

list3 = list(str)
print(list3)
# Out:
# ['A', 'n', 'g', 'u', 'r', 'a', 'j']

# %%
list4 = list((1,'angur',3.4,'a'
             ))
print(list4)
# Out:
# [1, 'angur', 3.4, 'a']

# %%
cart5 = ["toys","apple","banana",1,2,3,4,5]

cart5.insert(2,"guva")
cart5.append(245)
cart5.append(list4)
cart5.extend(list3)
cart5
# Out:
# ['toys',
#  'apple',
#  'guva',
#  'banana',
#  1,
#  2,
#  3,
#  4,
#  5,
#  245,
#  [1, 'angur', 3.4, 'a'],
#  'A',
#  'n',
#  'g',
#  'u',
#  'r',
#  'a',
#  'j']

# %%
cart6 = ["toys","apple","banana",1,2,3,4,5]


cart6.pop()
cart6.pop(2)
cart6.remove('apple')
cart6
# Out:
# ['toys', 1, 2, 3, 4]

# %%
cart7 = ["toys","apple","banana"]

cart7.sort()
cart7
# Out:
# ['apple', 'banana', 'toys']
