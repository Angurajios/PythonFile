# %%
#list functions

#append - Adding oneElement or list of element[] At Last
#extend - multiple element with [a,b,c] as [,,,a,b,c] at last
#insert - add element in specific position or index
#remove -  remove the element with name
#pop - remove the last element
#pop(index) - remove the element with specific index
#index - find index
#copy - to copy the list
#count - to count particular elments count("element)
#reverse - to reverse the list
#sort() - inbuild to ascending to decending -- sort(reverse = true)

#Operations

#min(variableName),max(variableName),sum(variableName)

# %%
cart5 = ["toys","apple","banana",1,2,3,4,5]

cart5.insert(2,"guva")
cart5.append(245)
cart5
# Out:
# ['toys', 'apple', 'guva', 'banana', 1, 2, 3, 4, 5, 245]

# %%
cart5.index("guva")
cart5
# Out:
# ['toys', 'apple', 'guva', 'banana', 1, 2, 3, 4, 5, 245]

# %%
a1 = cart5.copy()
a1
# Out:
# ['toys', 'apple', 'guva', 'banana', 1, 2, 3, 4, 5, 245]

# %%
cart5.count("apple")
# Out:
# 1

# %%
list5 = ["as","and","true","in",'a']
list5.sort(key = len)
list5
# Out:
# ['a', 'as', 'in', 'and', 'true']

# %%
list5.append(numbers)

# %%
list5
# Out:
# ['a', 'as', 'in', 'and', 'true', [245, 5, 4, 3, 2, 1]]

# %%
numbers = [1, 2, 3, 4, 5, 245]
min(numbers)
# Out:
# 1

# %%
max(numbers)
# Out:
# 245

# %%
len(numbers)
# Out:
# 6

# %%
sum(numbers)
# Out:
# 260

# %%
numbers.reverse()
numbers
# Out:
# [245, 5, 4, 3, 2, 1]

# %%
list6 = ["as","and","true","in",'a']

list6.reverse()
list6
# Out:
# ['a', 'in', 'true', 'and', 'as']

# %%
#tuple - 

--#orderd
--#Duplicates allowed
-- #index and slicing supported
-- #different dataTypes
-- # Immutable - difference from list)
-- ()

# %%
tuple1 = (1,2,3,"apple","mango")
tuple1.count(3)
# Out:
# 1

# %%
tuple1.index("apple")
# Out:
# 3

# %%
tuple1[0]
# Out:
# 1

# %%
tuple1[1:5]
# Out:
# (2, 3, 'apple', 'mango')

# %%
tuple1[0:5:2]
# Out:
# (1, 3, 'mango')

# %%
len(tuple1)
# Out:
# 5

# %% [raw]
# tuple1[-1]

# %%
tuple1[::-1]
# Out:
# ('mango', 'apple', 3, 2, 1)

# %%
# add two list in one then sort
list_1 = [34,2,8,23,7]
list2 = [100,345,8,94,77]

list_1.extend(list2)
list1.sort()
list1
# Out:
# [2, 7, 8, 8, 23, 34, 77, 94, 100, 345]

# %%
# count how many times an element in a list
list_3 = [100,345,8,94,77,43,2,1,345]
list_3.count(345)
# Out:
# 2

# %%
# remove an element from tuple
tuple2 = ("Anguraj", "Ashok",23,"Ishwary","Arun",123,"Santhiya")

l1 = list(tuple2)
l1.remove("Santhiya")
tuple2 = tuple(l1)
tuple2
# Out:
# ('Anguraj', 'Ashok', 23, 'Ishwary', 'Arun', 123)

# %%
# find the length of tuple

len(tuple3)
# Out:
# 6

# %% [markdown]
# #Sets
#
# --- unordered
# --- Duplicates notallowed
# --- partially mutable(only add and remove)
# --- {}

# %%
set1 = { 10,90,("angu","ashok")}
set1
# Out:
# {('angu', 'ashok'), 10, 90}

# %%
set1.add("Arun")
set1
# Out:
# {('angu', 'ashok'), 10, 90, 'Arun'}

# %%
set1.update(["ishwarya","Arun"])
set1
# Out:
# {('angu', 'ashok'), 10, 90, 'Arun', 'ishwarya'}

# %%
set1.remove("ishwarya")
set1
# Out:
# {90, 'Arun', 'Rajeswari'}

# %%
set1.update(["ishwarya","Ashok"])
set1
# Out:
# {90, 'Arun', 'Ashok', 'Rajeswari', 'ishwarya'}

# %%
set1.pop()
set1
# Out:
# {90, 'Arun', 'Ashok', 'Rajeswari'}

# %%
set1.discard("b")
