# %%
set1 = {78,4,34,5,2235,32,25,4}
set1
# Out:
# {4, 5, 25, 32, 34, 78, 2235}

# %%
#Sets

#Union --- combine all elements in single
#intersection - common element 
#SymmetricDifference -- remove common element and return remaining element in both
#Differnce -  remove common element and return remaining element in  one set
#isSubset - 
#isSuperSet - 
#isdisjoint -  check common element and return bool value based on thatif common not - true, if common elemt iruntha false
#intersectionUpdate - common elements update
# Out:
# 2235

# %%
set1 = {2,7,4,33,8}
set2  = {56,456,32,7,1}

set1.union(set2)
# Out:
# {1, 2, 4, 7, 8, 32, 33, 56, 456}

# %%
set1.intersection(set2)
# Out:
# {7}

# %%
set1.symmetric_difference(set2)
# Out:
# {1, 2, 4, 8, 32, 33, 56, 456}

# %%
set1.difference(set2)
# Out:
# {2, 4, 8, 33}

# %%
#1.Remove Duplicate fromn a list using sets

list1 = [78,4,34,5,2235,32,25,4]

set1 = set(list1)

list1 = list(set1)
list1
# Out:
# [32, 34, 4, 5, 78, 25, 2235]

# %%
#two set and check disjoint

set1 = {2,7,4,33,8}
set2  = {56,456,32,7,1}

set1.isdisjoint(set2)
# Out:
# False

# %%
#convert two list into sets and find intersection

list1 = [78,34,5,25,32,4]

list2 = [3,5,1,43,54,25,34]

set_1 = set(list1)
set_2 = set(list2)

set_1
# Out:
# {4, 5, 25, 32, 34, 78}

# %%
set_2
# Out:
# {1, 3, 5, 25, 34, 43, 54}

# %%
set_1.intersection(set_2)
# Out:
# {5, 25, 34}

# %%
#dictionary --------> store key Value pairs
#mutable
#keys unique
#value duplicates

#if duplicates there last value will be consider

# %%
student = {"name":"Anguraj","age":26,"City":"Tiruppur"}
student
# Out:
# {'name': 'Anguraj', 'age': 26, 'City': 'Tiruppur'}

# %%
student["age"]
# Out:
# 26

# %%
student["age"] = 17
student["age"]
# Out:
# 17

# %%
student["Course"] = "AI"
student
# Out:
# {'name': 'Anguraj', 'age': 17, 'City': 'Tiruppur', 'Course': 'AI'}

# %%
student["City"] = "Tiuppur"
student["Course"] = "AI"

# %%
student
# Out:
# {'name': 'Anguraj', 'age': 17, 'City': 'Tiuppur', 'Course': 'AI'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'City', 'Course'])

# %%
student.values()
# Out:
# dict_values(['Anguraj', 17, 'Tiuppur', 'AI'])

# %%
student.pop("age")
# Out:
# 17

# %%
del student["City"]

# %%
student
# Out:
# {'name': 'Anguraj', 'Course': 'AI'}

# %%
student_1 = {"name":"Anguraj","age":26,"City":"Tiruppur"}
student_1
# Out:
# {'name': 'Anguraj', 'age': 26, 'City': 'Tiruppur'}

# %%
#update --  merge two dict to 1
student_2 = {"City" : "Tiruppur", "Courses": "AI", "studentID":2}

student_1.update(student_2)

student_1
# Out:
# {'name': 'Anguraj',
#  'age': 26,
#  'City': 'Tiruppur',
#  'Courses': 'AI',
#  'studentID': 2}

# %%
student_1.setdefault("Zip")

student_1
# Out:
# {'name': 'Anguraj',
#  'age': 26,
#  'City': 'Tiruppur',
#  'Courses': 'AI',
#  'studentID': 2,
#  'Zip': None}

# %%
student_1.items()
# Out:
# dict_items([('name', 'Anguraj'), ('age', 26), ('City', 'Tiruppur'), ('Courses', 'AI'), ('studentID', 2), ('Zip', None)])

# %%
list_3 = ["name","age","address"]

d1 = dict.fromkeys(list_3,"unKnown")
d1
# Out:
# {'name': 'unKnown', 'age': 'unKnown', 'address': 'unKnown'}

# %%
d2 = student_1.copy()
d2
# Out:
# {'name': 'Anguraj',
#  'age': 26,
#  'City': 'Tiruppur',
#  'Courses': 'AI',
#  'studentID': 2,
#  'Zip': None}

# %%
len(d2)
# Out:
# 6
