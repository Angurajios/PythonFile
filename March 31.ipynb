# %% [markdown]
# variable----- Its containers to store values

# %%
a = 10
b = 5
a,b = b,a
print(a)
print(b)
print(type(a))
# Out:
# 5
# 10
# <class 'int'>

# %% [markdown]
# #dataTypes
#
# numeric - Int,float
# non-numeric - string,bool

# %%
#getting input fron user

userName = input("Enter the userName")
pw = int(input("passWord"))
# Out:
# Enter the userName Anguraj
# passWord 24323422

# %% [markdown]
# #typeCasting
#
# #implicit ----> conversion of small dataype to big datatype
# #explicit ----> conversion of big dataype to small datatype

# %%
x = 23
y = float(x)

print(x)
print(y)
# Out:
# 23
# 23.0

# %%
a = 23.8423
b = int(a)

print(a)
print(b)
# Out:
# 23.8423
# 23

# %%
#operators

#arithmetic-----(+,-,*,**,/,//,%)
#assignment ------ (= ,+=,*=,----->arithmetic plus ==)
#comparison ---- (<,>,<=,>=,==,!=)
#logical ----(And,or,not)
#bitwise-----((&,|, ^- exor, ~-(a+1))
#identity----(is, isnot) - check loaction and return bool value
#membership ----- in, not in) check value contains or not and return bool value

# %%
a = 8
b = 15

print(((a<b) and (a==b)))
print(((a<b) or (a==b)))

print(not(a<b))
# Out:
# False
# True
# False

# %%
num1 = 42
num2 = 6

print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 ** num2)
print(num1 / num2)
print(num1 // num2)
print(num1 % num2)
# Out:
# 48
# 36
# 252
# 5489031744
# 7.0
# 7
# 0

# %%
num1 = 42
num2 = 8

num1 -= num2
print(num1)
# Out:
# 34

# %%
x = "12"
y = "98"

print(int(x)+int(y))
# Out:
# 110

# %%
numb1 = 200
numb2 = 100

print(numb1 is numb2)
# Out:
# False

# %%
x=["apple","banana","cherry"]
y=["apple","banana","cherry"]
z=x

print(x is y)
print(z is x)
print(x is z)
print(x==y)
# Out:
# False
# True
# True
# True
