# %%
#nested Dict
#list inside dict

# %% [markdown]
# ##  Conditional Statements

# %%
#if else

user_input = int(input())

if user_input % 2 == 0:
    print(f"{user_input} is Even Number")
else:
    print(f"{user_input} is Odd Number")
# Out:
#  7
# Odd Number

# %%
user_input1 = int(input())


if user_input1 < 0:
    print(f"{user_input1} is Negative Number")
elif user_input1 == 0:
    print(f"{user_input1} is Zero")
else:
    print(f"{user_input1} is Positive")
# Out:
#  0
# 0 is Zero

# %%
studentMarks = int(input())

if studentMarks >= 90 and studentMarks <= 100:
    print(" A Grade")
elif studentMarks >= 80 and studentMarks <= 89:
    print(" B Grade")
elif studentMarks >= 70 and studentMarks <= 79:
    print(" C Grade")
elif studentMarks >= 60 and studentMarks <= 69:
    print(" D Grade")
elif studentMarks < 60:
    print(" F Grade")
else:
    print("Invalid marks")
# Out:
#  55
#  F Grade

# %%
number1 = int(input())
number2 = int(input())

if number1 > number2:
    print(f"{number1} is largest")
else:
    print(f"{number2} is largest")
# Out:
#  -55
#  2
# 2 is largest

# %%
voterAge = int(input())

if voterAge >= 18:
    print("Eligible for vote")
else:
    print("Not eligible)
# Out:
#  18
# Eligible for vote

# %%
userInput = int(input())

if userInput % 3 == 0 and userInput%5 == 0 :
    print("GivenNumber is divisble by 3 and 5")
else:
    print("GivenNumber is Not divisble by 3 and 5")
# Out:
#  45
# GivenNumber is divisble by 3 and 5

# %%
givenInteger = int(input())

if givenInteger > 0:
    print("givenNumber is Postive")
    if givenInteger % 2 == 0:
        print(f"{givenInteger} is Even Number")
    else:
        print(f"{givenInteger} is odd Number")
elif givenInteger < 0:
    print("GivenNumber is Negative")
    if abs(givenInteger) %5 == 0:
        print("Absolute value is multiple of 5")
    else:
        print("Absolute value is not multiple of 5")

else:

    print("Zero is neither postive nor negative")
# Out:
#  0
# Zero is neither postive nor negative

# %%
userName = input("Enter the UserName")
passWord = input("Enter the Password")

if userName == "admin":
    if passWord == "admin123":
        print("Login Sucessful")
    else:
        print("Password Wrong")
else:
    print("User Not Found")
# Out:
# Enter the UserName admi
# Enter the Password admin123
# User Not Found

# %%
acc_balance = 5500

withDrawn_Balance = int(input("Enter the Withdrawl Amount here"))

if withDrawn_Balance%100 == 0:
    if withDrawn_Balance<= acc_balance:
        print(f"Amount WithDrawl completed and you remaining balance is {acc_balance - withDrawn_Balance}")
    else:
        print("your withDrawl amount is Higher then accountBalance")
else:
    print("Invalid withdraw Amount!!, Enter the Multiples of 100")
# Out:
# Enter the Withdrawl Amount here 7000
# your withDrawl amount is Higher then accountBalance

# %% [markdown]
# ## Assesments

# %%
#1.marks are 50 or more, print "Pass"

mark = int(input())

if mark>=50:
    print("Pass")
else:
    print("Fail")
# Out:
#  66
# Pass

# %%
#2. leap year
year = int(input())

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("Leap year") 
        else:
            print("Not a leap year")  
    else:
        print("Leap year") 
else:
    print("Not a leap year")
# Out:
#  2004
# Leap year

# %%
#3. three numbers as Input and find smallest number

numb1 = int(input())
numb2 = int(input())
numb3 = int(input())

if numb1 < numb2 and numb1 < numb3:
    print(f"{numb1} is smallest")
elif numb2 < numb1 and numb2 < numb3:
    print(f"{numb2} is smallest")
else:
    print(f"{numb3} is smallest")
# Out:
#  7
#  23
#  1
# 1 is smallest

# %%
#4. FInd the case Sensitive of given Character
charc = input()
if charc.isupper():
    print(f"Given {charc} is Uppercase")
else:
    print(f"Given {charc} is LowerCase")
# Out:
#  3
# Given 3 is LowerCase

# %%
#5. Find triangle Type:

side1 = int(input())
side2 = int(input())
side3 = int(input())

if side1 + side2 > side3 and side2 + side3 > side1 and side1 + side3 > side2:
    if side1 == side2 == side3:
        print("It's Equilateral Triangle -> All three sides are equal")
    elif side1 == side2 or side2 == side3 or side1 == side3:
        print("Isosceles Triangle -> Exactly two sides are equal")
    else:
        print("Scalene Triangle → No sides are equal")
else:
    print("Invalid Triangle")
# Out:
#  2
#  2
#  2
# It's Equilateral Triangle -> All three sides are equal

# %%
#6. Leap year with respetcive condtion

year_1 = int(input("Enter a year: "))

if year_1 % 400 == 0:
    print(f"{year_1} is a Leap Year")
elif year_1 % 4 == 0 and year_1 % 100 != 0:
    print(f"{year_1} is a Leap Year")
else:
    print(f"{year_1} is Not a Leap Year")
# Out:
# Enter a year:  2004
# 2004 is a Leap Year

# %%
#find Ticket price based on age

personAge = int(input())

if personAge<5:
    print("the ticket is free")
elif personAge>=5 and personAge<=12:
    print("the ticket price is $5")
elif personAge>=13 and personAge<=60:
    print("the ticket price is $10")
else:
    print("the ticket price is $7.")
# Out:
#  1
# the ticket is free
